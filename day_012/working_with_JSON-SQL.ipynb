# %% [markdown]
# # **Working with JSON/SQL**

# %%
import pandas as pd

# %% [markdown]
# ## JSON (JavaScript Object Notation)
#
# - JSON is a universal data format, almost all programming languages support it.
# - The response from API calls is usually in JSON format.
# - JSON is easy to read and write for humans and easy to parse and generate for machines.

# %%
# reading JSON data
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
# reading JSON data from public url endpoint
pd.read_json('https://open.er-api.com/v6/latest/PKR')
# Out:
#       result                          provider  \
# PKR  success  https://www.exchangerate-api.com
# AED  success  https://www.exchangerate-api.com
# AFN  success  https://www.exchangerate-api.com
# ALL  success  https://www.exchangerate-api.com
# AMD  success  https://www.exchangerate-api.com
# ..       ...                               ...
# XPF  success  https://www.exchangerate-api.com
# YER  success  https://www.exchangerate-api.com
# ZAR  success  https://www.exchangerate-api.com
# ZMW  success  https://www.exchangerate-api.com
# ZWL  success  https://www.exchangerate-api.com
#
#                                   documentation  \
# PKR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ZWL  https://www.exchangerate-api.com/docs/free
#
#                                terms_of_use  time_last_update_unix  \
# PKR  https://www.exchangerate-api.com/terms             1760400151
# AED  https://www.exchangerate-api.com/terms             1760400151
# AFN  https://www.exchangerate-api.com/terms             1760400151
# ALL  https://www.exchangerate-api.com/terms             1760400151
# AMD  https://www.exchangerate-api.com/terms             1760400151
# ..                                      ...                    ...
# XPF  https://www.exchangerate-api.com/terms             1760400151
# YER  https://www.exchangerate-api.com/terms             1760400151
# ZAR  https://www.exchangerate-api.com/terms             1760400151
# ZMW  https://www.exchangerate-api.com/terms             1760400151
# ZWL  https://www.exchangerate-api.com/terms             1760400151
#
#                 time_last_update_utc  time_next_update_unix  \
# PKR  Tue, 14 Oct 2025 00:02:31 +0000             1760487101
# AED  Tue, 14 Oct 2025 00:02:31 +0000             1760487101
# AFN  Tue, 14 Oct 2025 00:02:31 +0000             1760487101
# ALL  Tue, 14 Oct 2025 00:02:31 +0000             1760487101
# AMD  Tue, 14 Oct 2025 00:02:31 +0000             1760487101
# ..                               ...                    ...
# XPF  Tue, 14 Oct 2025 00:02:31 +0000             1760487101
# YER  Tue, 14 Oct 2025 00:02:31 +0000             1760487101
# ZAR  Tue, 14 Oct 2025 00:02:31 +0000             1760487101
# ZMW  Tue, 14 Oct 2025 00:02:31 +0000             1760487101
# ZWL  Tue, 14 Oct 2025 00:02:31 +0000             1760487101
#
#                 time_next_update_utc  time_eol_unix base_code     rates
# PKR  Wed, 15 Oct 2025 00:11:41 +0000              0       PKR  1.000000
# AED  Wed, 15 Oct 2025 00:11:41 +0000              0       PKR  0.012972
# AFN  Wed, 15 Oct 2025 00:11:41 +0000              0       PKR  0.234662
# ALL  Wed, 15 Oct 2025 00:11:41 +0000              0       PKR  0.294797
# AMD  Wed, 15 Oct 2025 00:11:41 +0000              0       PKR  1.352017
# ..                               ...            ...       ...       ...
# XPF  Wed, 15 Oct 2025 00:11:41 +0000              0       PKR  0.364124
# YER  Wed, 15 Oct 2025 00:11:41 +0000              0       PKR  0.845008
# ZAR  Wed, 15 Oct 2025 00:11:41 +0000              0       PKR  0.061252
# ZMW  Wed, 15 Oct 2025 00:11:41 +0000              0       PKR  0.080351
# ZWL  Wed, 15 Oct 2025 00:11:41 +0000              0       PKR  0.094203
#
# [163 rows x 11 columns]

# %%
# API request
import requests

url = 'https://v6.exchangerate-api.com/v6/Your_API_Key/latest/USD' 
response = requests.get(url)
data = response.json()

# %%
df = pd.DataFrame([data])
df
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1760400001
#
#               time_last_update_utc  time_next_update_unix  \
# 0  Tue, 14 Oct 2025 00:00:01 +0000             1760486401
#
#               time_next_update_utc base_code  \
# 0  Wed, 15 Oct 2025 00:00:01 +0000       USD
#
#                                     conversion_rates
# 0  {'USD': 1, 'AED': 3.6725, 'AFN': 66.4279, 'ALL...

# %% [markdown]
# ## SQL (Structured Query Language)
#
# - SQL is a standard language for storing, manipulating, and retrieving data in databases.
# - SQL is used to communicate with a database.
# - SQL is used in various database systems like MySQL, PostgreSQL, SQLite, and more.

# %% [markdown]
# To work with SQL databases in Python, you can use libraries like `sqlite3` for SQLite databases or `mysql-connector` for MySQL databases.

# %%
# installing mysq;.connector 
# !pip install mysql.connector
# Out:
# Collecting mysql.connector
#   Downloading mysql-connector-2.2.9.tar.gz (11.9 MB)
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#      
/s eta 0:00:01
#      ---------------------------------------- 11.9/11.9 MB 504.3 kB/s  0:00:23
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: mysql.connector
#   Building wheel for mysql.connector (setup.py): started
#   Building wheel for mysql.connector (setup.py): finished with status 'done'
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp310-cp310-win_amd64.whl size=248038 sha256=e73badb8a18657276fef85b2719c637470084e535512fc0a22c53e11a2d7d61b
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\76\48\9b\da67ff1a18fe8e9d428f9b1a177716d4a7d363d2bbe83bf6cf
# Successfully built mysql.connector
# Installing collected packages: mysql.connector
# Successfully installed mysql.connector-2.2.9
#   DEPRECATION: Building 'mysql.connector' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'mysql.connector'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
import mysql.connector

# %%
# connecting to MySQL database
conn = mysql.connector.connect(host='localhost', user='root', password='', database='world')

# %%
# fetching data from SQL database
pd.read_sql_query('SELECT * FROM city', conn)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3844\3958920354.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('SELECT * FROM city', conn)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
# installing MySQL + SQLAlchemy support
# !pip install -q SQLAlchemy mysql-connector-python

# %%
# using SQLAlchemy
from sqlalchemy import create_engine
engine = create_engine("mysql+mysqlconnector://root:@localhost/world")
pd.read_sql_query("SELECT * FROM city", engine)
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
pak = pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'PAK'", engine)
pak.head()
# Out:
#      ID        Name CountryCode District  Population
# 0  2822     Karachi         PAK    Sindh     9269265
# 1  2823      Lahore         PAK   Punjab     5063499
# 2  2824  Faisalabad         PAK   Punjab     1977246
# 3  2825  Rawalpindi         PAK   Punjab     1406214
# 4  2826      Multan         PAK   Punjab     1182441

# %%
punjab = pd.read_sql_query("SELECT * FROM city WHERE District LIKE 'Punjab'", engine)
punjab.head()
# Out:
#      ID                   Name CountryCode District  Population
# 0  1039               Ludhiana         IND   Punjab     1042740
# 1  1054               Amritsar         IND   Punjab      708835
# 2  1071  Jalandhar (Jullundur)         IND   Punjab      509510
# 3  1129                Patiala         IND   Punjab      238368
# 4  1192    Bhatinda (Bathinda)         IND   Punjab      159042

# %%
asia = pd.read_sql_query("SELECT * FROM country WHERE continent LIKE 'Asia'", engine)
asia.head()
# Out:
#   Code                  Name Continent                     Region  \
# 0  AFG           Afghanistan      Asia  Southern and Central Asia
# 1  ARE  United Arab Emirates      Asia                Middle East
# 2  ARM               Armenia      Asia                Middle East
# 3  AZE            Azerbaijan      Asia                Middle East
# 4  BGD            Bangladesh      Asia  Southern and Central Asia
#
#    SurfaceArea  IndepYear  Population  LifeExpectancy      GNP   GNPOld  \
# 0     652090.0     1919.0    22720000            45.9   5976.0      NaN
# 1      83600.0     1971.0     2441000            74.1  37966.0  36846.0
# 2      29800.0     1991.0     3520000            66.4   1813.0   1627.0
# 3      86600.0     1991.0     7734000            62.9   4127.0   4100.0
# 4     143998.0     1971.0   129155000            60.2  32852.0  31966.0
#
#                             LocalName      GovernmentForm  \
# 0               Afganistan/Afqanestan     Islamic Emirate
# 1  Al-Imarat al-´Arabiya al-Muttahida  Emirate Federation
# 2                            Hajastan            Republic
# 3                          Azärbaycan    Federal Republic
# 4                          Bangladesh            Republic
#
#                    HeadOfState  Capital Code2
# 0                Mohammad Omar        1    AF
# 1  Zayid bin Sultan al-Nahayan       65    AE
# 2             Robert Kotšarjan      126    AM
# 3                Heydär Äliyev      144    AZ
# 4            Shahabuddin Ahmad      150    BD
